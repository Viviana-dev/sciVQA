# %%
from PIL import Image
from IPython.display import display

img = Image.open("/home/vivianav/sciVQA/data/images/train/images_train/Y18-1063.pdf-Figure11.png")  # Replace this
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=625x172>
